# %%
import pandas as pd

# %%
pd.read_excel('Test File.xlsx')
# Out:
#     Sr. no         Name   Age  Year of Birth Gender       Date  Salary
# 0        1          Baba   82           1939      M 2017-08-01   50000
# 1        2           Aai   80           1941      F 2019-10-08   50000
# 2        3    Dilip Kaka   64           1957      M 2019-10-08  200000
# 3        4  Vandana Kaki   60           1961      F 2019-10-08   30000
# 4        5          Papa   61           1960      M 2019-10-08  100000
# 5        6         Mammi   56           1965      F 2019-10-08   40000
# 6        7     Papu Kaka   59           1962      M 2019-10-08  100000
# 7        8    Anita Kaki   56           1965      F 2019-10-08   40000
# 8        9   Mayura Didi   36           1985      F 2019-10-08   30000
# 9       10          Ajay   31           1990      M 2019-10-08  200000
# 10      11        Shikha   30           1991      F 2019-10-08   40000
# 11      12        Akshay   31           1990      M 2019-10-08   25000
# ...

# %%
pd.read_excel('Test File.xlsx')
# Out:
#     Sr. no         Name   Age  Year of Birth Gender       Date  Salary
# 0        1          Baba   82           1939      M 2017-08-01   50000
# 1        2           Aai   80           1941      F 2019-10-08   50000
# 2        3    Dilip Kaka   64           1957      M 2019-10-08  200000
# 3        4  Vandana Kaki   60           1961      F 2019-10-08   30000
# 4        5          Papa   61           1960      M 2019-10-08  100000
# 5        6         Mammi   56           1965      F 2019-10-08   40000
# 6        7     Papu Kaka   59           1962      M 2019-10-08  100000
# 7        8    Anita Kaki   56           1965      F 2019-10-08   40000
# 8        9   Mayura Didi   36           1985      F 2019-10-08   30000
# 9       10          Ajay   31           1990      M 2019-10-08  200000
# 10      11        Shikha   30           1991      F 2019-10-08   40000
# 11      12        Akshay   31           1990      M 2019-10-08   25000
# ...

# %%
data = pd.read_excel('Test File.xlsx')

# %%
data.iloc[0,0]= 34

# %%
data
# Out:
#     Sr. no         Name   Age  Year of Birth Gender       Date  Salary
# 0       34          Baba   82           1939      M 2017-08-01   50000
# 1        2           Aai   80           1941      F 2019-10-08   50000
# 2        3    Dilip Kaka   64           1957      M 2019-10-08  200000
# 3        4  Vandana Kaki   60           1961      F 2019-10-08   30000
# 4        5          Papa   61           1960      M 2019-10-08  100000
# 5        6         Mammi   56           1965      F 2019-10-08   40000
# 6        7     Papu Kaka   59           1962      M 2019-10-08  100000
# 7        8    Anita Kaki   56           1965      F 2019-10-08   40000
# 8        9   Mayura Didi   36           1985      F 2019-10-08   30000
# 9       10          Ajay   31           1990      M 2019-10-08  200000
# 10      11        Shikha   30           1991      F 2019-10-08   40000
# 11      12        Akshay   31           1990      M 2019-10-08   25000
# ...

# %%
data.to_excel('Test File.xlsx', sheet_name = 'Sheet3')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-10-5208c601330a> in <module>
# ----> 1 data.to_excel('Test File.xlsx', sheet_name = 'Sheet1')
#
# c:\users\adnin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2282             inf_rep=inf_rep,
#    2283         )
# -> 2284         formatter.write(
#    2285             excel_writer,
#    2286             sheet_name=sheet_name,
#
# c:\users\adnin\appdata\local\programs\python\python38\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
# ...
